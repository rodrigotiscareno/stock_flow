# %%
data = yf.download('AAPL','2016-01-01','2023-06-18')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   25.652500   26.342501   25.500000   26.337500   24.041489
# 2016-01-05   26.437500   26.462500   25.602501   25.677500   23.439024
# 2016-01-06   25.139999   25.592501   24.967501   25.174999   22.980330
# 2016-01-07   24.670000   25.032499   24.107500   24.112499   22.010452
# 2016-01-08   24.637501   24.777500   24.190001   24.240000   22.126837
# ...                ...         ...         ...         ...         ...
# 2023-06-12  181.270004  183.889999  180.970001  183.789993  183.789993
# 2023-06-13  182.800003  184.149994  182.440002  183.309998  183.309998
# 2023-06-14  183.369995  184.389999  182.020004  183.949997  183.949997
# 2023-06-15  183.960007  186.520004  183.779999  186.009995  186.009995
# 2023-06-16  186.729996  186.990005  184.270004  184.919998  184.919998
#
#                Volume
# Date
# ...

# %%
tickerSymbol = 'AAPL'
tickerData = yf.Ticker(tickerSymbol)
tickerData.history(period='1d', interval='10m')

# [1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]
# Out:
# AAPL: Invalid input - interval=10m is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
import yfinance as yf

tickerSymbol = 'AAPL'
tickerData = yf.Ticker(tickerSymbol)

dividends = tickerData.dividends
print(dividends)

splits = tickerData.splits
print(splits)
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2022-05-06 00:00:00-04:00    0.230000
# 2022-08-05 00:00:00-04:00    0.230000
# 2022-11-04 00:00:00-04:00    0.230000
# 2023-02-10 00:00:00-05:00    0.230000
# 2023-05-12 00:00:00-04:00    0.240000
# Name: Dividends, Length: 79, dtype: float64
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
import yfinance as yf
import pandas as pd
tickerSymbol = 'AAPL'
tickerData = yf.Ticker(tickerSymbol)

info = tickerData.info
l = pd.DataFrame(info).columns
list(l)

# %%
from yahooquery import Ticker

company = Ticker('AAPL')

balance_sheet = company.balance_sheet()

income_statement = company.income_statement()
cash_flow = company.cash_flow()

cash_flow
# Out:
#          asOfDate periodType currencyCode  BeginningCashPosition  \
# symbol
# AAPL   2019-09-30        12M          USD           2.591300e+10
# AAPL   2020-09-30        12M          USD           5.022400e+10
# AAPL   2021-09-30        12M          USD           3.978900e+10
# AAPL   2022-09-30        12M          USD           3.592900e+10
# AAPL   2022-12-31        TTM          USD           3.863000e+10
# AAPL   2023-03-31        TTM          USD           2.918000e+10
#
#         CapitalExpenditure  CashDividendsPaid  \
# symbol
# AAPL         -1.049500e+10      -1.411900e+10
# AAPL         -7.309000e+09      -1.408100e+10
# AAPL         -1.108500e+10      -1.446700e+10
# AAPL         -1.070800e+10      -1.484100e+10
# AAPL         -1.169200e+10      -1.487700e+10
# AAPL         -1.209400e+10      -1.493200e+10
#
#         CashFlowFromContinuingFinancingActivities  \
# symbol
# AAPL                                -9.097600e+10
# ...

# %%
from yahooquery import Ticker

stock = Ticker('AAPL')
profile = stock.summary_profile
pd.DataFrame(profile)
# Out:
#                                                                   AAPL
# address1                                            One Apple Park Way
# city                                                         Cupertino
# companyOfficers                                                     []
# country                                                  United States
# fullTimeEmployees                                               164000
# industry                                          Consumer Electronics
# industryDisp                                      Consumer Electronics
# longBusinessSummary  Apple Inc. designs, manufactures, and markets ...
# maxAge                                                           86400
# phone                                                     408 996 1010
# sector                                                      Technology
# state                                                               CA
# ...

# %%
from yahooquery import Ticker

stock = Ticker('AAPL')
stats = stock.key_stats
pd.DataFrame(stats)
# Out:
#                                              AAPL
# 52WeekChange                             0.361007
# SandP52WeekChange                        0.171271
# beta                                     1.289436
# bookValue                                   3.953
# category                                     None
# dateShortInterest             2023-05-30 19:00:00
# earningsQuarterlyGrowth                    -0.034
# enterpriseToEbitda                          23.93
# enterpriseToRevenue                         7.692
# enterpriseValue                     2962294571008
# floatShares                           15712029576
# forwardEps                                   6.56
# forwardPE                               28.189024
# fundFamily                                   None
# heldPercentInsiders                       0.00071
# heldPercentInstitutions                   0.61232
# impliedSharesOutstanding              15728700416
# lastDividendDate                       1683849600
# ...

# %%
from yahooquery import Ticker

stock = Ticker('AAPL')
earnings = stock.earnings
earnings
# Out:
# {'AAPL': {'maxAge': 86400,
#   'earningsChart': {'quarterly': [{'date': '2Q2022',
#      'actual': 1.2,
#      'estimate': 1.16},
#     {'date': '3Q2022', 'actual': 1.29, 'estimate': 1.27},
#     {'date': '4Q2022', 'actual': 1.88, 'estimate': 1.94},
#     {'date': '1Q2023', 'actual': 1.52, 'estimate': 1.43}],
#    'currentQuarterEstimate': 1.19,
#    'currentQuarterEstimateDate': '2Q',
#    'currentQuarterEstimateYear': 2023,
#    'earningsDate': ['2023-07-26 15:00:S', '2023-07-31 15:00:S']},
#   'financialsChart': {'yearly': [{'date': 2019,
#      'revenue': 260174000000,
#      'earnings': 55256000000},
#     {'date': 2020, 'revenue': 274515000000, 'earnings': 57411000000},
#     {'date': 2021, 'revenue': 365817000000, 'earnings': 94680000000},
#     {'date': 2022, 'revenue': 394328000000, 'earnings': 99803000000}],
#    'quarterly': [{'date': '2Q2022',
#      'revenue': 82959000000,
#      'earnings': 19442000000},
# ...

# %%
from yahooquery import Ticker

stock = Ticker('AAPL')
recommendations = stock.recommendation_trend
pd.DataFrame(recommendations)
# Out:
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# AAPL   0       0m         11   21     6     0           0
#        1      -1m          9   24     7     1           0
#        2      -2m          9   24     7     1           0
#        3      -3m         13   20     8     0           0

# %%
from yahooquery import Ticker

stock = Ticker('AAPL')
holders = stock.major_holders
print(holders)
# Out:
# {'AAPL': {'maxAge': 1, 'insidersPercentHeld': 0.00071000005, 'institutionsPercentHeld': 0.61232, 'institutionsFloatPercentHeld': 0.61275, 'institutionsCount': 5743}}

# %%
from yahooquery import Ticker

stock = Ticker('AAPL')
options = stock.option_chain
pd.DataFrame(options)
# Out:
#                                    contractSymbol  strike currency  lastPrice  \
# symbol expiration optionType
# AAPL   2023-06-23 calls       AAPL230623C00070000    70.0      USD     108.57
#                   calls       AAPL230623C00100000   100.0      USD      79.80
#                   calls       AAPL230623C00110000   110.0      USD      75.93
#                   calls       AAPL230623C00115000   115.0      USD      70.92
#                   calls       AAPL230623C00120000   120.0      USD      65.89
# ...                                           ...     ...      ...        ...
#        2025-12-19 puts        AAPL251219P00260000   260.0      USD      86.91
#                   puts        AAPL251219P00270000   270.0      USD      96.76
#                   puts        AAPL251219P00290000   290.0      USD     116.36
#                   puts        AAPL251219P00300000   300.0      USD     115.44
#                   puts        AAPL251219P00310000   310.0      USD     127.02
#
# ...

# %%
from yahooquery import Ticker

# Initialize a Ticker object with multiple ticker symbols
stocks = Ticker(['AAPL', 'GOOG', 'MSFT'])

# Fetch balance sheet data for all stocks
balance_sheets = stocks.balance_sheet()

# Fetch other financial data for all stocks
income_statements = stocks.income_statement()
cash_flows = stocks.cash_flow()

# Print the data
income_statements
# Out:
#          asOfDate periodType currencyCode  BasicAverageShares  BasicEPS  \
# symbol
# AAPL   2019-09-30        12M          USD        1.847134e+10  2.992500
# AAPL   2020-09-30        12M          USD        1.735212e+10  3.310000
# AAPL   2021-09-30        12M          USD        1.670127e+10  5.670000
# AAPL   2022-09-30        12M          USD        1.621596e+10  6.150000
# AAPL   2022-12-31        TTM          USD                 NaN       NaN
# AAPL   2023-03-31        TTM          USD                 NaN       NaN
# GOOG   2019-12-31        12M          USD        1.385191e+10  2.479501
# GOOG   2020-12-31        12M          USD        1.361631e+10  2.957501
# GOOG   2021-12-31        12M          USD        1.335299e+10  5.694003
# GOOG   2022-12-31        12M          USD        1.306300e+10  4.590000
# GOOG   2022-12-31        TTM          USD                 NaN       NaN
# GOOG   2023-03-31        TTM          USD                 NaN       NaN
# ...
